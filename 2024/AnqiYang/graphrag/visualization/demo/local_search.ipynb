# %%
# Copyright (c) 2024 Microsoft Corporation.
# Licensed under the MIT License.

# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.input.loaders.dfs import (
    store_entity_semantic_embeddings,
)
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.question_gen.local_gen import LocalQuestionGen
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore

# %%
os.environ["GRAPHRAG_API_KEY"] = ''
os.environ["GRAPHRAG_LLM_MODEL"] = 'gpt-4o-mini-mini'
os.environ["GRAPHRAG_EMBEDDING_MODEL"] = 'text-embedding-3-small'

# %% [markdown]
# ## Local Search Example
#
# Local search method generates answers by combining relevant data from the AI-extracted knowledge-graph with text chunks of the raw documents. This method is suitable for questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?).

# %% [markdown]
# ### Load text units and graph data tables as context for local search
#
# - In this test we first load indexing outputs from parquet files to dataframes, then convert these dataframes into collections of data objects aligning with the knowledge model.

# %% [markdown]
# ### Load tables to dataframes

# %%
INPUT_DIR = "./inputs/operation dulce"
LANCEDB_URI = f"{INPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COVARIATE_TABLE = "create_final_covariates"
TEXT_UNIT_TABLE = "create_final_text_units"
COMMUNITY_LEVEL = 2

# %% [markdown]
# #### Read entities

# %%
# read nodes table to get community and degree data
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

# load description embeddings to an in-memory lancedb vectorstore
# to connect to a remote db, specify url and port values.
description_embedding_store = LanceDBVectorStore(
    collection_name="entity_description_embeddings",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)
entity_description_embeddings = store_entity_semantic_embeddings(
    entities=entities, vectorstore=description_embedding_store
)

print(f"Entity count: {len(entity_df)}")
entity_df.head()
# Out:
# Entity count: 434
#    level                      title          type  \
# 0      0                ALEX MERCER        PERSON
# 1      0                TAYLOR CRUZ        PERSON
# 2      0               JORDAN HAYES        PERSON
# 3      0                 SAM RIVERA        PERSON
# 4      0  PARANORMAL MILITARY SQUAD  ORGANIZATION
#
#                                          description  \
# 0  Alex Mercer is a character with a military bac...
# 1  Taylor Cruz is a character who plays a pivotal...
# 2  Dr. Jordan Hayes is a key character in a narra...
# 3  Sam Rivera is a character renowned for their t...
# 4  The Paranormal Military Squad is an elite clan...
#
#                                            source_id community  degree  \
# 0  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1       9
# 1  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      12
# 2  00fafabae48948779fee2afe600f5143,2cf7a230c367a...         1       9
# 3  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      15
# 4  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      14
#
#    human_readable_id                                id  size graph_embedding  \
# 0                  0  b45241d70f0e43fca764df95b2b81f77     9            None
# 1                  1  4119fd06010c494caa07f439b333f4c5    12            None
# 2                  2  d3835bf3dda84ead99deadbeac5d0d7d     9            None
# 3                  3  077d2820ae1845bcbb1803379a3d1eae    15            None
# 4                  4  3671ea0dd4e84c1a9b02c5ab2c8f4bac    14            None
#
#   entity_type                 top_level_node_id  x  y
# 0        None  b45241d70f0e43fca764df95b2b81f77  0  0
# 1        None  4119fd06010c494caa07f439b333f4c5  0  0
# 2        None  d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3        None  077d2820ae1845bcbb1803379a3d1eae  0  0
# 4        None  3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0

# %%
entity_df.head()
# Out:
#    level                      title          type  \
# 0      0                ALEX MERCER        PERSON
# 1      0                TAYLOR CRUZ        PERSON
# 2      0               JORDAN HAYES        PERSON
# 3      0                 SAM RIVERA        PERSON
# 4      0  PARANORMAL MILITARY SQUAD  ORGANIZATION
#
#                                          description  \
# 0  Alex Mercer is a character with a military bac...
# 1  Taylor Cruz is a character who plays a pivotal...
# 2  Dr. Jordan Hayes is a key character in a narra...
# 3  Sam Rivera is a character renowned for their t...
# 4  The Paranormal Military Squad is an elite clan...
#
#                                            source_id community  degree  \
# 0  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1       9
# 1  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      12
# 2  00fafabae48948779fee2afe600f5143,2cf7a230c367a...         1       9
# 3  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      15
# 4  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      14
#
#    human_readable_id                                id  size graph_embedding  \
# 0                  0  b45241d70f0e43fca764df95b2b81f77     9            None
# 1                  1  4119fd06010c494caa07f439b333f4c5    12            None
# 2                  2  d3835bf3dda84ead99deadbeac5d0d7d     9            None
# 3                  3  077d2820ae1845bcbb1803379a3d1eae    15            None
# 4                  4  3671ea0dd4e84c1a9b02c5ab2c8f4bac    14            None
#
#   entity_type                 top_level_node_id  x  y
# 0        None  b45241d70f0e43fca764df95b2b81f77  0  0
# 1        None  4119fd06010c494caa07f439b333f4c5  0  0
# 2        None  d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3        None  077d2820ae1845bcbb1803379a3d1eae  0  0
# 4        None  3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0

# %% [markdown]
# #### Read relationships

# %%
relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

print(f"Relationship count: {len(relationship_df)}")
relationship_df.head()
# Out:
# Relationship count: 276
#         source        target  weight  \
# 0  ALEX MERCER   TAYLOR CRUZ     7.0
# 1  ALEX MERCER   TAYLOR CRUZ     7.0
# 2  ALEX MERCER   TAYLOR CRUZ     7.0
# 3  ALEX MERCER   TAYLOR CRUZ     7.0
# 4  ALEX MERCER  JORDAN HAYES     6.0
#
#                                          description  \
# 0  Alex Mercer and Taylor Cruz are integral membe...
# 1  Alex Mercer and Taylor Cruz are integral membe...
# 2  Alex Mercer and Taylor Cruz are integral membe...
# 3  Alex Mercer and Taylor Cruz are integral membe...
# 4  Alex Mercer and Jordan Hayes are colleagues wh...
#
#                                        text_unit_ids  \
# 0  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 1  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 2  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 3  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 4  [00fafabae48948779fee2afe600f5143, 2cf7a230c36...
#
#                                  id human_readable_id  source_degree  \
# 0  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 1  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 2  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 3  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 4  a97e2ecd870944cfbe71c79bc0fcc752                 1              9
#
#    target_degree  rank
# 0             12    21
# 1             12    21
# 2             12    21
# 3             12    21
# 4              9    18

# %%
covariate_df = pd.read_parquet(f"{INPUT_DIR}/{COVARIATE_TABLE}.parquet")

claims = read_indexer_covariates(covariate_df)

print(f"Claim records: {len(claims)}")
covariates = {"claims": claims}
# Out:
# Claim records: 89

# %% [markdown]
# #### Read community reports

# %%
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)

print(f"Report records: {len(report_df)}")
report_df.head()
# Out:
# Report records: 6
#   community                                       full_content  level  rank  \
# 0         4  # Dulce Base and the Paranormal Military Squad...      1   8.5
# 1         5  # Sam Rivera and the Paranormal Military Squad...      1   7.5
# 2         0  # Dulce Base and the Paranormal Military Squad...      0   8.5
# 3         1  # Dulce Base and the Paranormal Military Squad...      0   8.5
# 4         2  # Dulce Base: Extraterrestrial Research and Co...      0   8.5
#
#                                                title  \
# 0  Dulce Base and the Paranormal Military Squad: ...
# 1  Sam Rivera and the Paranormal Military Squad a...
# 2  Dulce Base and the Paranormal Military Squad Team
# 3  Dulce Base and the Paranormal Military Squad: ...
# 4  Dulce Base: Extraterrestrial Research and Comm...
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The impact severity rating is high due to the ...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is high due to the ...
# 4  The impact severity rating is high due to the ...
#
#                                              summary  \
# 0  The community is centered around Dulce Base, a...
# 1  The community is centered around Sam Rivera, a...
# 2  Dulce Base serves as the operational hub for t...
# 3  The community is centered around Dulce Base, a...
# 4  Dulce Base is a highly classified facility in ...
#
#                                             findings  \
# 0  [{'explanation': 'Dulce Base is the primary lo...
# 1  [{'explanation': 'Sam Rivera is recognized for...
# 2  [{'explanation': 'The Paranormal Military Squa...
# 3  [{'explanation': 'Sam Rivera is recognized for...
# 4  [{'explanation': 'Dulce Base is the epicenter ...
#
#                                    full_content_json  \
# 0  {\n    "title": "Dulce Base and the Paranormal...
# 1  {\n    "title": "Sam Rivera and the Paranormal...
# 2  {\n    "title": "Dulce Base and the Paranormal...
# 3  {\n    "title": "Dulce Base and the Paranormal...
# 4  {\n    "title": "Dulce Base: Extraterrestrial ...
#
#                                      id
# 0  6f8ba6b6-506e-46c1-83ce-982d59622554
# 1  418f4536-d673-4212-8a7c-ca1aac547d0f
# 2  251df57e-fd49-49a7-b262-ccaff95d7a51
# 3  6e536385-8056-4a82-8670-c0ccaf007fb4
# 4  660c8fba-b65f-4fcd-9c98-203600cf1981

# %% [markdown]
# #### Read text units

# %%
text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

print(f"Text unit records: {len(text_unit_df)}")
text_unit_df.head()
# Out:
# Text unit records: 12
#                                  id  \
# 0  2cf7a230c367a2dfaf0fc3c903eb8948
# 1  6d1255303acb7c9dc951cb0f5fc3042c
# 2  e841f178310356740b2ee9101d12c97f
# 3  f36d96862b9366d7240b5c7ceb04f12b
# 4  f7d43808d2fb452cd953bf50c6de6bd4
#
#                                                 text  n_tokens  \
# 0  # Operation: Dulce\n\n## Chapter 1\n\nThe thru...      2500
# 1   be the same.\n\n\*\n\nThe sense of foreboding...      2500
# 2  . "Your take on these signal inconsistencies?"...      2500
# 3  , absorbed in the bewilderment of contact, whi...      2500
# 4   were at once coherent and enigmatic: "*Voyage...      2500
#
#                          document_ids  \
# 0  [958fdd043f17ade63cb13570b59df295]
# 1  [958fdd043f17ade63cb13570b59df295]
# 2  [958fdd043f17ade63cb13570b59df295]
# 3  [958fdd043f17ade63cb13570b59df295]
# 4  [958fdd043f17ade63cb13570b59df295]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 3  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 4  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
#
#                                     relationship_ids  \
# 0  [b35c3d1a7daa4924b6bdb58bc69c354d, a97e2ecd870...
# 1  [b35c3d1a7daa4924b6bdb58bc69c354d, a97e2ecd870...
# 2  [b35c3d1a7daa4924b6bdb58bc69c354d, a97e2ecd870...
# 3  [b35c3d1a7daa4924b6bdb58bc69c354d, 09f18f81442...
# 4  [e02be3e37ca0454883a4c1fd859c24bb, 1dbc51475cb...
#
#                                        covariate_ids
# 0  [ad5a2020-cdec-4982-acdf-dbe5ee530066, 9d8a0fe...
# 1  [5d1c9126-c48d-4755-9f9c-f739c823f95f, ec64a42...
# 2  [0b22a34b-32e9-46a4-a0e8-d3d5466eba15, 7e14972...
# 3  [9cd6d645-ab97-4b39-b02e-647cea9b5545, 50dc124...
# 4             [87cf5900-6211-4e04-9115-50f3617c88b4]

# %%
api_key =  os.environ["GRAPHRAG_API_KEY"]
llm_model = os.environ["GRAPHRAG_LLM_MODEL"]
embedding_model = os.environ["GRAPHRAG_EMBEDDING_MODEL"]

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

text_embedder = OpenAIEmbedding(
    api_key=api_key,
    api_base=None,
    api_type=OpenaiApiType.OpenAI,
    model=embedding_model,
    deployment_name=embedding_model,
    max_retries=20,
)

# %% [markdown]
# ### Create local search context builder

# %%
context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    covariates=covariates,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

# %% [markdown]
# ### Create local search engine

# %%
# text_unit_prop: proportion of context window dedicated to related text units
# community_prop: proportion of context window dedicated to community reports.
# The remaining proportion is dedicated to entities and relationships. Sum of text_unit_prop and community_prop should be <= 1
# conversation_history_max_turns: maximum number of turns to include in the conversation history.
# conversation_history_user_turns_only: if True, only include user queries in the conversation history.
# top_k_mapped_entities: number of related entities to retrieve from the entity description embedding store.
# top_k_relationships: control the number of out-of-network relationships to pull into the context window.
# include_entity_rank: if True, include the entity rank in the entity table in the context window. Default entity rank = node degree.
# include_relationship_weight: if True, include the relationship weight in the context window.
# include_community_rank: if True, include the community rank in the context window.
# return_candidate_context: if True, return a set of dataframes containing all candidate entity/relationship/covariate records that
# could be relevant. Note that not all of these records will be included in the context window. The "in_context" column in these
# dataframes indicates whether the record is included in the context window.
# max_tokens: maximum number of tokens to use for the context window.


local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

llm_params = {
    "max_tokens": 2_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

# %%
search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %% [markdown]
# ### Run local search on sample queries

# %%
result = await search_engine.asearch("Tell me about Agent Mercer")
print(result.response)
# Out:
# ### Agent Alex Mercer: A Key Figure in Interstellar Communication
#
# Agent Alex Mercer is a pivotal member of the Paranormal Military Squad, a team dedicated to interstellar communication and extraterrestrial engagement. Mercer's role within the squad is characterized by leadership, strategic planning, and a diplomatic approach to potential extraterrestrial contact [Data: Entities (156); Claims (37, 41, 45, 50, +more)].
#
# #### Leadership and Diplomatic Role
#
# Mercer is recognized for guiding the team in their mission to establish contact with alien intelligence. His leadership style is marked by a balance of authority and collaboration, which is crucial for the success of the squad's objectives. Mercer’s diplomatic approach is particularly important in the delicate and potentially perilous task of engaging with extraterrestrial beings. His ability to navigate complex situations and maintain team cohesion underscores his importance within the squad [Data: Entities (156); Claims (37, 41, 45, 50, +more)].
#
# #### Collaborative Dynamics
#
# The relationship dynamics between Mercer and other key team members, such as Taylor Cruz and Dr. Jordan Hayes, highlight the collaborative yet complex nature of the squad's hierarchy and decision-making processes. Mercer’s interactions with these individuals reflect mutual respect and reliance on each other's expertise, which is essential for the squad's mission [Data: Relationships (0, 5, 8, 4)].
#
# #### Strategic Planning and Execution
#
# Mercer’s strategic planning capabilities are evident in his approach to the squad's operations. He is often seen orchestrating the team's efforts with precision, ensuring that every move is calculated and purposeful. This meticulous planning is crucial in the high-stakes environment of interstellar communication, where the margin for error is minimal [Data: Sources (7)].
#
# #### First Contact and Beyond
#
# Mercer’s role becomes even more significant in the context of the suspected first contact with extraterrestrial intelligence. His leadership and strategic foresight are instrumental in navigating this unprecedented event, which has the potential to alter humanity's understanding of the universe. The squad's covert operations and the sensitive nature of their mission underscore the high impact severity rating of their activities, with Mercer at the helm [Data: Claims (48, 65, 66, 72); Entities (157); Relationships (39, 44, 47, 43)].
#
# ### Conclusion
#
# Agent Alex Mercer stands out as a central figure in the Paranormal Military Squad, whose leadership, strategic planning, and diplomatic skills are vital to the team's mission of interstellar communication. His ability to collaborate effectively with other key members and navigate the complexities of potential extraterrestrial contact highlights his indispensable role in this high-stakes endeavor.

# %%
question = "Tell me about Dr. Jordan Hayes"
result = await search_engine.asearch(question)
print(result.response)
# Out:
# ## Dr. Jordan Hayes: A Key Figure in Extraterrestrial Communication
#
# Dr. Jordan Hayes is a pivotal member of the Paranormal Military Squad stationed at Dulce Base, primarily responsible for decrypting and analyzing alien signals. Hayes' role is crucial in the squad's mission to establish contact with extraterrestrial intelligence, leveraging their analytical and methodical approach to decode complex alien messages [Data: Entities (2); Claims (36, 39, 42, +more)].
#
# ### Analytical Expertise and Methodical Approach
#
# Dr. Hayes is renowned for their analytical mindset, which is essential in the investigation and interpretation of alien communications. Their logical and methodical approach ensures that the team can systematically decode and understand the alien signals, which are often encrypted and complex [Data: Entities (124); Claims (36, 39, 42, +more)]. This expertise is critical in transforming seemingly indecipherable alien codes into comprehensible data that can be used to facilitate communication with extraterrestrial beings.
#
# ### Collaboration and Team Dynamics
#
# Within the Paranormal Military Squad, Dr. Hayes collaborates closely with other key members, including Taylor Cruz and Alex Mercer. Their interactions with these team members reflect a balance of authority and collaboration, which is vital for the success of their mission. Hayes' relationship with Sam Rivera, another integral member of the squad, is particularly noteworthy. Together, they work on deciphering the alien code, combining their skills to enhance the team's overall capability in handling extraterrestrial communications [Data: Relationships (1, 24, 22, 40)].
#
# ### Role in Decrypting Alien Signals
#
# Dr. Hayes leads the efforts in decrypting and interpreting alien signals, a task that requires a high level of skepticism and analytical rigor. Their work involves not only breaking down the alien code but also understanding the underlying patterns and motifs within the signals. This process is crucial for establishing a reliable line of communication with extraterrestrial intelligence, which is a primary objective of the Paranormal Military Squad [Data: Entities (201, 178); Claims (36, 39, 42, +more)].
#
# ### Impact on the Mission
#
# The contributions of Dr. Hayes are instrumental in the squad's suspected first contact with extraterrestrial beings. Their ability to decode and analyze alien messages has significant implications for humanity's understanding of the universe and its place within it. The success of the Paranormal Military Squad's mission heavily relies on Hayes' expertise and their ability to work effectively with the rest of the team [Data: Claims (48, 65, 66, 72); Relationships (39, 44, 47, 43)].
#
# In summary, Dr. Jordan Hayes is a central figure in the Paranormal Military Squad's efforts to communicate with extraterrestrial intelligence. Their analytical skills, collaborative spirit, and leadership in decrypting alien signals make them indispensable to the mission at Dulce Base.

# %% [markdown]
# #### Inspecting the context data used to generate the response

# %%
print(result.context_data["entities"])
# Out:
#      id                                          entity  \
# 0   137                                      WASHINGTON
# 1   201                                      DECRYPTION
# 2    82                             AGENT MICHAEL BROWN
# 3   208                                 YOUTHFUL MEMBER
# 4   128                                         SILENCE
# 5   161                        COMMUNICATION ENCRYPTION
# 6   101                  EXTRATERRESTRIAL COMMUNICATION
# 7   178                                      ALIEN CODE
# 8   196                 TRANSLATING ALIEN COMMUNICATION
# 9   205   MEASURED RESPONSE TO EXTRATERRESTRIAL CONTACT
# 10  132                                         CONCERN
# 11  103                  PARANORMAL MILITARY SQUAD TEAM
# 12  174                               YOUTHFUL OPTIMISM
# 13  194  PROTOCOL FOR RESPONDING TO ALIEN COMMUNICATION
# 14   56                             AGENT PATRICK BROWN
# 15    3                                      SAM RIVERA
# 16   41                                 DR. AARON YOUNG
# 17  175                               CAUTIOUS APPROACH
# 18  118                                      MENTORSHIP
# 19  124                              ANALYTICAL MINDSET
#
#                                           description number of relationships  \
# 0   The capital of the United States, possibly the...                       1
# 1   Decryption is the process of converting encode...                       0
# 2   Agent Michael Brown is a high-risk personnel s...                       0
# 3   A younger individual who is part of a team, br...                       0
# 4   A characteristic of the Dulce military base, c...                       0
# 5   The method of securing communication, which Sa...                       0
# 6                                                                           1
# 7   The "ALIEN CODE" refers to the cryptic languag...                       0
# 8   The act of converting the alien messages into ...                       0
# 9   The calculated and deliberate reaction of the ...                       0
# 10  An emotion felt by Alex Mercer, combined with ...                       0
# 11  The Paranormal Military Squad Team is a specia...                       7
# 12  A characteristic of Sam Rivera, bringing a pos...                       0
# 13  The guidelines and procedures developed by the...                       0
# 14  Agent Patrick Brown is an explosive ordnance d...                       0
# 15  Sam Rivera is a character renowned for their t...                      15
# 16  Dr. Aaron Young is an astrophysicist in the Pa...                       0
# 17  The strategy employed by Alex Mercer in leadin...                       0
# 18  Mentorship refers to the relationship dynamic ...                       0
# 19  The logical and methodical approach that Jorda...                       0
#
#     in_context
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True

# %%
result.context_data["relationships"]
# Out:
#     id                          source                          target  \
# 0   38                      SAM RIVERA  PARANORMAL MILITARY SQUAD TEAM
# 1   35                      SAM RIVERA                      DULCE BASE
# 2   63                      DULCE BASE  PARANORMAL MILITARY SQUAD TEAM
# 3   54  EXTRATERRESTRIAL COMMUNICATION                      DULCE BASE
# 4   31                      SAM RIVERA       PARANORMAL MILITARY SQUAD
# 5   10                     TAYLOR CRUZ                      SAM RIVERA
# 6   34                      SAM RIVERA                DR. JORDAN HAYES
# 7   37                      SAM RIVERA               AGENT ALEX MERCER
# 8   19                     TAYLOR CRUZ  PARANORMAL MILITARY SQUAD TEAM
# 9   41       PARANORMAL MILITARY SQUAD                      WASHINGTON
# 10  64  PARANORMAL MILITARY SQUAD TEAM                DR. JORDAN HAYES
# 11  65  PARANORMAL MILITARY SQUAD TEAM               AGENT ALEX MERCER
# 12   2                     ALEX MERCER                      SAM RIVERA
# 13  21                    JORDAN HAYES                      SAM RIVERA
# 14  33                      SAM RIVERA                OPERATION: DULCE
# 15  28                      SAM RIVERA                            CRUZ
# 16  36                      SAM RIVERA              DECRYPTION PROCESS
# 17  27                      SAM RIVERA           OPTIMISM AND INTRIGUE
# 18  29                      SAM RIVERA                          TAYLOR
# 19  30                      SAM RIVERA                          MERCER
# 20  32                      SAM RIVERA        EXTRATERRESTRIAL SIGNALS
# 21  66  PARANORMAL MILITARY SQUAD TEAM        EXTRATERRESTRIAL CONTACT
# 22  52              FIRST CONTACT DATA  PARANORMAL MILITARY SQUAD TEAM
#
#                                           description weight rank links  \
# 0   Sam Rivera is a member of the Paranormal Milit...    1.0   22     1
# 1   Sam Rivera is part of the Dulce Base team, con...    1.0   32     3
# 2   Dulce Base is the location where the Paranorma...    1.0   24     3
# 3   Dulce Base serves as a central hub for efforts...    3.0   18     3
# 4   Sam Rivera is the youngest member of the Paran...    7.0   29     2
# 5   Taylor Cruz and Sam Rivera are colleagues at D...    8.0   27     2
# 6   Dr. Jordan Hayes and Sam Rivera are colleagues...    1.0   22     2
# 7   Alex Mercer interacts with Sam Rivera regardin...    1.0   21     2
# 8   Taylor Cruz is a member of the Paranormal Mili...    1.0   19     2
# 9   The Paranormal Military Squad team is in commu...    1.0   15     2
# 10  Dr. Jordan Hayes is a key analytical member of...    1.0   14     2
# 11  Agent Alex Mercer is a key member of the Paran...    1.0   13     2
# 12  Alex Mercer and Sam Rivera are teammates in th...    5.0   24     1
# 13  Jordan Hayes and Sam Rivera are colleagues at ...    5.0   24     1
# 14  Sam Rivera is working on communication aspects...    1.0   22     1
# 15  Cruz and Sam Rivera are both part of the same ...    1.0   18     1
# 16  Sam Rivera contributes to the decryption proce...    1.0   17     1
# 17  Sam Rivera's approach to extraterrestrial cont...    2.0   16     1
# 18  Taylor seeks counsel from Sam Rivera, indicati...    1.0   16     1
# 19  Sam Rivera's actions are a testament to the me...    1.0   16     1
# 20  Sam Rivera is involved in the analysis and res...    2.0   16     1
# 21  The Paranormal Military Squad team is responsi...    1.0    8     1
# 22  The Paranormal Military Squad Team at Dulce Ba...    3.0    8     1
#
#     in_context
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True

# %%
result.context_data["reports"].head()
# Out:
#   id                                              title  \
# 0  4  Dulce Base and the Paranormal Military Squad: ...
#
#                                              content
# 0  # Dulce Base and the Paranormal Military Squad...

# %%
result.context_data["sources"].head()
# Out:
#   id                                               text
# 0  3  , absorbed in the bewilderment of contact, whi...
# 1  8  ences the full spectrum of human curiosity and...

# %%
if "claims" in result.context_data:
    print(result.context_data["claims"].head())
# Out:
#    id                          entity object_id     status start_date  \
# 0  46  PARANORMAL MILITARY SQUAD TEAM      NONE       TRUE       NONE
# 1  58  PARANORMAL MILITARY SQUAD TEAM      NONE  SUSPECTED       NONE
# 2  59  PARANORMAL MILITARY SQUAD TEAM      NONE  SUSPECTED       NONE
# 3  83  PARANORMAL MILITARY SQUAD TEAM      NONE  SUSPECTED       NONE
# 4  88  PARANORMAL MILITARY SQUAD TEAM      NONE       TRUE       NONE
#
#   end_date                                        description  in_context
# 0     NONE  The team's mission evolved from observation to...        True
# 1     NONE  The Paranormal Military Squad team navigates t...        True
# 2     NONE  The Paranormal Military Squad team is preparin...        True
# 3     NONE  The Paranormal Military Squad team is engaged ...        True
# 4     NONE  The Paranormal Military Squad team stood as hu...        True

# %% [markdown]
# ### Question Generation

# %% [markdown]
# This function takes a list of user queries and generates the next candidate questions.

# %%
question_generator = LocalQuestionGen(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
)

# %%
question_history = [
    "Tell me about Agent Mercer",
    "What happens in Dulce military base?",
]
candidate_questions = await question_generator.agenerate(
    question_history=question_history, context_data=None, question_count=5
)
print(candidate_questions.response)
# Out:
# ['- What is the significance of Operation: Dulce?', '- Who are the key members of the Paranormal Military Squad involved in Operation: Dulce?', '- How does the environment of New Mexico impact the mission at Dulce Military Base?', "- What role does Sam Rivera play in the Paranormal Military Squad's mission at Dulce Base?", '- What are the main challenges faced by the team at Dulce Military Base?']
